# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import tensorflow as tf
import random
import time
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D,MaxPooling2D,Dropout,InputLayer
from tensorflow.keras.utils import to_categorical,plot_model
from tensorflow.keras.applications import MobileNetV3Large
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.metrics import classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
import cv2
import math

# %%
path = "../germany_dataset/train.csv"
df = pd.read_csv(path)
df = df.dropna()
df['Rotate'] = 0

# %%
df["length"] = df["Roi.X2"]-df["Roi.X1"]
df["height"] = df["Roi.Y2"]-df["Roi.Y1"]
df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path  Rotate  length  height
# 0  Train/20/00020_00000_00000.png       0      17      15
# 1  Train/20/00020_00000_00001.png       0      18      16
# 2  Train/20/00020_00000_00002.png       0      18      16
# 3  Train/20/00020_00000_00003.png       0      18      16
# 4  Train/20/00020_00000_00004.png       0      18      16

# %%
df.describe()
# Out:
#               Width        Height        Roi.X1        Roi.Y1        Roi.X2  \
# count  39209.000000  39209.000000  39209.000000  39209.000000  39209.000000
# mean      50.835880     50.328930      5.999515      5.962381     45.197302
# std       24.306933     23.115423      1.475493      1.385440     23.060157
# min       25.000000     25.000000      0.000000      5.000000     20.000000
# 25%       35.000000     35.000000      5.000000      5.000000     29.000000
# 50%       43.000000     43.000000      6.000000      6.000000     38.000000
# 75%       58.000000     58.000000      6.000000      6.000000     53.000000
# max      243.000000    225.000000     20.000000     20.000000    223.000000
#
#              Roi.Y2       ClassId   Rotate        length        height
# count  39209.000000  39209.000000  39209.0  39209.000000  39209.000000
# mean      44.728379     15.788390      0.0     39.197786     38.765998
# std       21.971145     12.013238      0.0     21.821369     20.828697
# min       20.000000      0.000000      0.0     15.000000     15.000000
# 25%       30.000000      5.000000      0.0     24.000000     24.000000
# 50%       38.000000     12.000000      0.0     33.000000     32.000000
# 75%       52.000000     25.000000      0.0     47.000000     47.000000
# max      205.000000     42.000000      0.0    203.000000    185.000000

# %%
# All Variables declaration to use same code for different datasets
num_of_classes = df["ClassId"].nunique()
resize_x  = 50
resize_y  = 50
num_of_channels = 3
directory = "../germany_dataset/"
testdir = "../germany_dataset/test.csv"
Epochs=25
train_length = len(df)

# %%
# Necessary Functions
def remove_outlier(df,parameter):
    Percentile25 = df[parameter].quantile(0.25)
    Percentile75 = df[parameter].quantile(0.75)
    iqr = Percentile75 - Percentile25
    lowerlimit = Percentile25 - 1.5*iqr
    upperlimit = Percentile75 + 1.5*iqr
    temp1 = df[parameter]>lowerlimit
    temp2 = df[parameter]<upperlimit
    return df[temp1 & temp2] 

def get_max_index(arr):
    length = len(arr)
    mini = 0
    value = 0
    for i,val in enumerate(arr):
        if mini < val :
            mini = val
            value = i
    return value

def viewStatistics(df):
    #Statistics of Data
    print("Total Training Examples : ",len(df))
    values = df["ClassId"].value_counts()
    x_labels = [str(x) for x in range(num_of_classes)]
    y_labels = []
    for x in range(num_of_classes):
        y_labels.append(values[x])
    plt.figure(figsize=(15, 6))
    plt.bar(x_labels,y_labels,width=0.5)
    plt.title('Bar Graph')
    plt.xlabel('Class')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()
    
def upSampleDataFrame(df,upSampleCount=300):
    starting_time = time.time()
    classes = {}

    for val in range(num_of_classes):
        classes[val]=[]

    max_repeating = 0

    for index,row in df.iterrows():
        classes[row.values[6]].append(row.values)

    row = []
    for i in range(num_of_classes):
        length = len(classes[i])
        want = upSampleCount - length
        for j in range(len(classes[i])):
            row.append(classes[i][j])
        if(want<=0):
            continue
        for j in range(want):
            select_image = random.randint(0,length-1)
            angle = random.randint(0,359)
            f = classes[i][select_image].copy()
            f[8] = angle
            row.append(f)
    np.random.shuffle(row)

    df = pd.DataFrame(row,columns = df.columns)

    ending_time = time.time()
    total_time = ending_time - starting_time
    total_time/=60
    print("Total number of images after Upsampling: ", len(df))
    print("\n\nTime taken to upsample images : ",total_time," min")
    return df

def Predict_for_single_example(model,img):
    img  = np.array(img)
    img  = tf.convert_to_tensor(img,dtype=float)
    img = img/255.0
    img = tf.expand_dims(img, axis=0)
    probability = model.predict(img)
    value = get_max_index(probability[0])
    return value
    
def Predict_for_Multiple_examples(model,images):
    img = []
    for j in range(len(images)):
        img.append(np.array(images[j]))
    img = np.array(img)
    img = tf.convert_to_tensor(img,dtype=float)
    img = img/255.0
    probability = model.predict(img,verbose=False)
    values = []
    for val in probability:
        values.append(get_max_index(val))
    return values

def PredictTest(model,df,start,length):
    images = []
    y_test = []
    length = min(length,len(df)-start)
    for i in range(length):
        row = df.loc[start+i].values
        images.append(Image.open(directory+row[7]).crop((row[2],row[3],row[4],row[5])).rotate(row[8]).resize((resize_x,resize_y)))
        y_test.append(row[6])

    y_predicted = Predict_for_Multiple_examples(model,images)

    return y_test,y_predicted

def PredictTest(model,df):
    y_test = []
    y_predicted=[]
    length = len(df)
    batchSize = 750
    batchCounts = math.ceil(length/batchSize)
    for j in range(batchCounts):
        images = []
        if(j == batchCounts-1):
            for row in (df.iloc[j*batchSize:,:].values):
                images.append(Image.open(directory+row[7]).crop((row[2],row[3],row[4],row[5])).rotate(row[8]).resize((resize_x,resize_y)))
                y_test.append(row[6]) 
        else :       
            for i in range(batchSize):
                row = df.loc[i].values
                images.append(Image.open(directory+row[7]).crop((row[2],row[3],row[4],row[5])).rotate(row[8]).resize((resize_x,resize_y)))
                y_test.append(row[6])

        y_predicted.extend(Predict_for_Multiple_examples(model,images))

    return y_test,y_predicted

# %%
#Statistics of Data
viewStatistics(df)
# Out:
# Total Training Examples :  39209

# %%
# df = remove_outlier(df,"length")
# df = remove_outlier(df,"height")

# %%
#Statistics of Data
viewStatistics(df)
# Out:
# Total Training Examples :  39209

# %%
train_length = len(df)
print("Total Training Examples : ",len(df))
# Out:
# Total Training Examples :  39209

# %%
df = upSampleDataFrame(df,2000)
viewStatistics(df)
# Out:
# Total number of images after Upsampling:  86810
#
#
# Time taken to upsample images :  0.09533517360687256  min
# Total Training Examples :  86810

# %%
# Sample Images and there crop according to data given in csv
def resize_and_center(image, target_height, target_width):
        original_height, original_width= image.size
        height_ratio = target_height / original_height
        width_ratio = target_width / original_width
        resize_ratio = min(height_ratio, width_ratio)
        new_height = int(original_height * resize_ratio)
        new_width = int(original_width * resize_ratio)
        image  = np.array(image)
        resized_image = cv2.resize(image, (new_width, new_height))
        pad_height = max(0, (target_height - new_height) // 2)
        pad_width = max(0, (target_width - new_width) // 2)
        centered_image = cv2.copyMakeBorder(resized_image, pad_height, target_height - new_height - pad_height,pad_width, target_width - new_width - pad_width,cv2.BORDER_CONSTANT, value=(255, 255, 255))
        return centered_image
def showExamples(df):
    num_rows = 5
    num_cols = 2
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 20))
    total_images = []
    for i in range(5):
        integer = random.randint(0,len(df))
        total_images.append(df.iloc[integer].values)
    total_images = list(total_images)
    for i,val in enumerate(total_images):
        row = i
        col=0
        ax = axes[row, col]
        img = Image.open(directory+val[7])
        ax.imshow(img)
        img = img.crop((val[2],val[3],val[4],val[5]))
        img = img.rotate(val[8])
        img = resize_and_center(img,resize_x,resize_y)
        ax = axes[row,col+1]
        ax.imshow(img)
    ax.set_title(f'Image {i + 1}')
    ax.axis('off')

# %%
class Data:
    def __init__(self,df,size_x,size_y):
        self.df = df
        self.root = directory
        self.resize_x = size_x
        self.resize_y = size_y
    
    def resize_and_center(self,image, target_height, target_width):
        original_height, original_width= image.size
        height_ratio = target_height / original_height
        width_ratio = target_width / original_width
        resize_ratio = min(height_ratio, width_ratio)
        new_height = int(original_height * resize_ratio)
        new_width = int(original_width * resize_ratio)
        image  = np.array(image)
        resized_image = cv2.resize(image, (new_width, new_height))
        pad_height = max(0, (target_height - new_height) // 2)
        pad_width = max(0, (target_width - new_width) // 2)
        centered_image = cv2.copyMakeBorder(resized_image, pad_height, target_height - new_height - pad_height,pad_width, target_width - new_width - pad_width,cv2.BORDER_CONSTANT, value=(255, 255, 255))
        return centered_image

    def Do_Crop(self,path,x1,y1,x2,y2,r):
        img = Image.open(self.root+path)
        img = img.crop((x1,y1,x2,y2))
        img = img.rotate(r)
        img = self.resize_and_center(img,self.resize_x,self.resize_y)
        img = np.array(img,dtype=float)
        return img
    
    def Row_Data(self,row):
        self.X.append(self.Do_Crop(row.iloc[7],row.iloc[2],row.iloc[3],row.iloc[4],row.iloc[5],row.iloc[8]))
        self.Y.append(int(row.iloc[6]))
    
    def Get_Data(self,length):
        self.X = []
        self.Y = []
        want = [0]*num_of_classes
        for i in range(len(self.df)):
            row = self.df.iloc[i]
            if(want[int(row.iloc[6])]<length):
                want[int(row.iloc[6])] = want[int(row.iloc[6])]+1
                self.Row_Data(row)
        self.X = np.array(self.X)
        self.Y = np.array(self.Y,dtype=int)
        
    def Get_Data(self):
        self.X = []
        self.Y = []
        for i in range(len(self.df)):
            row = self.df.iloc[i]
            self.Row_Data(row)
        self.X = np.array(self.X)
        self.Y = np.array(self.Y,dtype=int)

# %%
showExamples(df)

# %%
def miniDataTrain(model,df):
    data = Data(df,resize_x,resize_y)
    data.Get_Data()
    X_train = data.X
    Y_train = data.Y
    X_train = X_train/255.0
    history = model.fit(X_train,Y_train,epochs=Epochs,batch_size=32,validation_split=0.1)
    return history    

def fullDataTrain(model,df,batchsize=2000):
    num_train = len(df)
    num_mini_trains = math.ceil(num_train/batchsize)
    print("Total Mini Trainings : ", num_mini_trains)
    for i in range(num_mini_trains):
        if(num_mini_trains == i+1):
            df1 = df.iloc[i*batchsize:,:]
            miniDataTrain(model,df1)
        else :
            df1 = df.iloc[i*batchsize:(i+1)*batchsize,:]
            miniDataTrain(model,df1)

# %%
# Load pre-trained ResNet50 model with random weights
model = MobileNetV3Large(weights=None, input_shape=(resize_x, resize_y, 3), classes=num_of_classes)

# Display the model summary
model.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50, 50, 3)]  0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 50, 50, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 25, 25, 16)   432         rescaling[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, 25, 25, 16)   64          Conv[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 25, 25, 16)   0           Conv/BatchNorm[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 25, 25, 16)   0           tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 25, 25, 16)   0           re_lu[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 25, 25, 16)   0           Conv/BatchNorm[0][0]
#                                                                  tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise (Depthw (None, 25, 25, 16)   144         multiply[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise/BatchNo (None, 25, 25, 16)   64          expanded_conv/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 25, 25, 16)   0           expanded_conv/depthwise/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv/project (Conv2D)  (None, 25, 25, 16)   256         re_lu_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv/project/BatchNorm (None, 25, 25, 16)   64          expanded_conv/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv/Add (Add)         (None, 25, 25, 16)   0           multiply[0][0]
#                                                                  expanded_conv/project/BatchNorm[0
# __________________________________________________________________________________________________
# expanded_conv_1/expand (Conv2D) (None, 25, 25, 64)   1024        expanded_conv/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/expand/BatchNor (None, 25, 25, 64)   256         expanded_conv_1/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 25, 25, 64)   0           expanded_conv_1/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise/pad ( (None, 27, 27, 64)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise (Dept (None, 13, 13, 64)   576         expanded_conv_1/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise/Batch (None, 13, 13, 64)   256         expanded_conv_1/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 13, 13, 64)   0           expanded_conv_1/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_1/project (Conv2D (None, 13, 13, 24)   1536        re_lu_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/project/BatchNo (None, 13, 13, 24)   96          expanded_conv_1/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/expand (Conv2D) (None, 13, 13, 72)   1728        expanded_conv_1/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_2/expand/BatchNor (None, 13, 13, 72)   288         expanded_conv_2/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 13, 13, 72)   0           expanded_conv_2/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_2/depthwise (Dept (None, 13, 13, 72)   648         re_lu_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/depthwise/Batch (None, 13, 13, 72)   288         expanded_conv_2/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 13, 13, 72)   0           expanded_conv_2/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_2/project (Conv2D (None, 13, 13, 24)   1728        re_lu_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/project/BatchNo (None, 13, 13, 24)   96          expanded_conv_2/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/Add (Add)       (None, 13, 13, 24)   0           expanded_conv_1/project/BatchNorm
#                                                                  expanded_conv_2/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_3/expand (Conv2D) (None, 13, 13, 72)   1728        expanded_conv_2/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/expand/BatchNor (None, 13, 13, 72)   288         expanded_conv_3/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 13, 13, 72)   0           expanded_conv_3/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise/pad ( (None, 17, 17, 72)   0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise (Dept (None, 7, 7, 72)     1800        expanded_conv_3/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise/Batch (None, 7, 7, 72)     288         expanded_conv_3/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 7, 7, 72)     0           expanded_conv_3/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 72)     0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 24)     1752        expanded_conv_3/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 24)     0           expanded_conv_3/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 72)     1800        expanded_conv_3/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 1, 1, 72)     0           expanded_conv_3/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 1, 1, 72)     0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 1, 1, 72)     0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 7, 7, 72)     0           re_lu_7[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/project (Conv2D (None, 7, 7, 40)     2880        expanded_conv_3/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_3/project/BatchNo (None, 7, 7, 40)     160         expanded_conv_3/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/expand (Conv2D) (None, 7, 7, 120)    4800        expanded_conv_3/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_4/expand/BatchNor (None, 7, 7, 120)    480         expanded_conv_4/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 7, 7, 120)    0           expanded_conv_4/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_4/depthwise (Dept (None, 7, 7, 120)    3000        re_lu_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/depthwise/Batch (None, 7, 7, 120)    480         expanded_conv_4/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 7, 7, 120)    0           expanded_conv_4/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 120)    0           re_lu_10[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 32)     3872        expanded_conv_4/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 32)     0           expanded_conv_4/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 120)    3960        expanded_conv_4/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 1, 1, 120)    0           expanded_conv_4/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 1, 1, 120)    0           tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 1, 1, 120)    0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 7, 7, 120)    0           re_lu_10[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/project (Conv2D (None, 7, 7, 40)     4800        expanded_conv_4/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_4/project/BatchNo (None, 7, 7, 40)     160         expanded_conv_4/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/Add (Add)       (None, 7, 7, 40)     0           expanded_conv_3/project/BatchNorm
#                                                                  expanded_conv_4/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_5/expand (Conv2D) (None, 7, 7, 120)    4800        expanded_conv_4/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/expand/BatchNor (None, 7, 7, 120)    480         expanded_conv_5/expand[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 7, 7, 120)    0           expanded_conv_5/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_5/depthwise (Dept (None, 7, 7, 120)    3000        re_lu_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/depthwise/Batch (None, 7, 7, 120)    480         expanded_conv_5/depthwise[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 7, 7, 120)    0           expanded_conv_5/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 120)    0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 32)     3872        expanded_conv_5/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 32)     0           expanded_conv_5/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 120)    3960        expanded_conv_5/squeeze_excite/Re
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 1, 1, 120)    0           expanded_conv_5/squeeze_excite/Co
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 1, 1, 120)    0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 1, 1, 120)    0           re_lu_14[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 7, 7, 120)    0           re_lu_13[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/project (Conv2D (None, 7, 7, 40)     4800        expanded_conv_5/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_5/project/BatchNo (None, 7, 7, 40)     160         expanded_conv_5/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/Add (Add)       (None, 7, 7, 40)     0           expanded_conv_4/Add[0][0]
#                                                                  expanded_conv_5/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_6/expand (Conv2D) (None, 7, 7, 240)    9600        expanded_conv_5/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/expand/BatchNor (None, 7, 7, 240)    960         expanded_conv_6/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 7, 7, 240)    0           expanded_conv_6/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 7, 7, 240)    0           tf.__operators__.add_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 7, 7, 240)    0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 7, 7, 240)    0           expanded_conv_6/expand/BatchNorm[
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise/pad ( (None, 9, 9, 240)    0           multiply_1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise (Dept (None, 4, 4, 240)    2160        expanded_conv_6/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise/Batch (None, 4, 4, 240)    960         expanded_conv_6/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 4, 4, 240)    0           expanded_conv_6/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 4, 4, 240)    0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 4, 4, 240)    0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4, 4, 240)    0           expanded_conv_6/depthwise/BatchNo
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/project (Conv2D (None, 4, 4, 80)     19200       multiply_2[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/project/BatchNo (None, 4, 4, 80)     320         expanded_conv_6/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/expand (Conv2D) (None, 4, 4, 200)    16000       expanded_conv_6/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_7/expand/BatchNor (None, 4, 4, 200)    800         expanded_conv_7/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 4, 4, 200)    0           expanded_conv_7/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 4, 4, 200)    0           tf.__operators__.add_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 4, 4, 200)    0           re_lu_17[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 4, 4, 200)    0           expanded_conv_7/expand/BatchNorm[
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/depthwise (Dept (None, 4, 4, 200)    1800        multiply_3[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/depthwise/Batch (None, 4, 4, 200)    800         expanded_conv_7/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 4, 4, 200)    0           expanded_conv_7/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 4, 4, 200)    0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 4, 4, 200)    0           re_lu_18[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 4, 4, 200)    0           expanded_conv_7/depthwise/BatchNo
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/project (Conv2D (None, 4, 4, 80)     16000       multiply_4[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/project/BatchNo (None, 4, 4, 80)     320         expanded_conv_7/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/Add (Add)       (None, 4, 4, 80)     0           expanded_conv_6/project/BatchNorm
#                                                                  expanded_conv_7/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_8/expand (Conv2D) (None, 4, 4, 184)    14720       expanded_conv_7/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/expand/BatchNor (None, 4, 4, 184)    736         expanded_conv_8/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None, 4, 4, 184)    0           expanded_conv_8/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 4, 4, 184)    0           tf.__operators__.add_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 4, 4, 184)    0           re_lu_19[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 4, 4, 184)    0           expanded_conv_8/expand/BatchNorm[
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise (Dept (None, 4, 4, 184)    1656        multiply_5[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise/Batch (None, 4, 4, 184)    736         expanded_conv_8/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 4, 4, 184)    0           expanded_conv_8/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 4, 4, 184)    0           tf.__operators__.add_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 4, 4, 184)    0           re_lu_20[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 4, 4, 184)    0           expanded_conv_8/depthwise/BatchNo
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/project (Conv2D (None, 4, 4, 80)     14720       multiply_6[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/project/BatchNo (None, 4, 4, 80)     320         expanded_conv_8/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/Add (Add)       (None, 4, 4, 80)     0           expanded_conv_7/Add[0][0]
#                                                                  expanded_conv_8/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_9/expand (Conv2D) (None, 4, 4, 184)    14720       expanded_conv_8/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/expand/BatchNor (None, 4, 4, 184)    736         expanded_conv_9/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_10 (TFOpLa (None, 4, 4, 184)    0           expanded_conv_9/expand/BatchNorm[
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 4, 4, 184)    0           tf.__operators__.add_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 4, 4, 184)    0           re_lu_21[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 4, 4, 184)    0           expanded_conv_9/expand/BatchNorm[
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/depthwise (Dept (None, 4, 4, 184)    1656        multiply_7[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/depthwise/Batch (None, 4, 4, 184)    736         expanded_conv_9/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_11 (TFOpLa (None, 4, 4, 184)    0           expanded_conv_9/depthwise/BatchNo
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 4, 4, 184)    0           tf.__operators__.add_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 4, 4, 184)    0           re_lu_22[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 4, 4, 184)    0           expanded_conv_9/depthwise/BatchNo
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/project (Conv2D (None, 4, 4, 80)     14720       multiply_8[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/project/BatchNo (None, 4, 4, 80)     320         expanded_conv_9/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/Add (Add)       (None, 4, 4, 80)     0           expanded_conv_8/Add[0][0]
#                                                                  expanded_conv_9/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_10/expand (Conv2D (None, 4, 4, 480)    38400       expanded_conv_9/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/expand/BatchNo (None, 4, 4, 480)    1920        expanded_conv_10/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_12 (TFOpLa (None, 4, 4, 480)    0           expanded_conv_10/expand/BatchNorm
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 4, 4, 480)    0           tf.__operators__.add_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 4, 4, 480)    0           re_lu_23[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 4, 4, 480)    0           expanded_conv_10/expand/BatchNorm
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/depthwise (Dep (None, 4, 4, 480)    4320        multiply_9[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/depthwise/Batc (None, 4, 4, 480)    1920        expanded_conv_10/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_13 (TFOpLa (None, 4, 4, 480)    0           expanded_conv_10/depthwise/BatchN
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 4, 4, 480)    0           tf.__operators__.add_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 4, 4, 480)    0           re_lu_24[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 4, 4, 480)    0           expanded_conv_10/depthwise/BatchN
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 480)    0           multiply_10[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 120)    57720       expanded_conv_10/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 120)    0           expanded_conv_10/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 480)    58080       expanded_conv_10/squeeze_excite/R
# __________________________________________________________________________________________________
# tf.__operators__.add_14 (TFOpLa (None, 1, 1, 480)    0           expanded_conv_10/squeeze_excite/C
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 1, 1, 480)    0           tf.__operators__.add_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 1, 1, 480)    0           re_lu_25[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 4, 4, 480)    0           multiply_10[0][0]
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/project (Conv2 (None, 4, 4, 112)    53760       expanded_conv_10/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_10/project/BatchN (None, 4, 4, 112)    448         expanded_conv_10/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/expand (Conv2D (None, 4, 4, 672)    75264       expanded_conv_10/project/BatchNor
# __________________________________________________________________________________________________
# expanded_conv_11/expand/BatchNo (None, 4, 4, 672)    2688        expanded_conv_11/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_15 (TFOpLa (None, 4, 4, 672)    0           expanded_conv_11/expand/BatchNorm
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 4, 4, 672)    0           tf.__operators__.add_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 4, 4, 672)    0           re_lu_26[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 4, 4, 672)    0           expanded_conv_11/expand/BatchNorm
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/depthwise (Dep (None, 4, 4, 672)    6048        multiply_11[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/depthwise/Batc (None, 4, 4, 672)    2688        expanded_conv_11/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_16 (TFOpLa (None, 4, 4, 672)    0           expanded_conv_11/depthwise/BatchN
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 4, 4, 672)    0           tf.__operators__.add_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 4, 4, 672)    0           re_lu_27[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 4, 4, 672)    0           expanded_conv_11/depthwise/BatchN
#                                                                  tf.math.multiply_16[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/squeeze_excite (None, 1, 1, 672)    0           multiply_12[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/squeeze_excite (None, 1, 1, 168)    113064      expanded_conv_11/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_11/squeeze_excite (None, 1, 1, 168)    0           expanded_conv_11/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_11/squeeze_excite (None, 1, 1, 672)    113568      expanded_conv_11/squeeze_excite/R
# __________________________________________________________________________________________________
# tf.__operators__.add_17 (TFOpLa (None, 1, 1, 672)    0           expanded_conv_11/squeeze_excite/C
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 1, 1, 672)    0           tf.__operators__.add_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 1, 1, 672)    0           re_lu_28[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/squeeze_excite (None, 4, 4, 672)    0           multiply_12[0][0]
#                                                                  tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/project (Conv2 (None, 4, 4, 112)    75264       expanded_conv_11/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_11/project/BatchN (None, 4, 4, 112)    448         expanded_conv_11/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_11/Add (Add)      (None, 4, 4, 112)    0           expanded_conv_10/project/BatchNor
#                                                                  expanded_conv_11/project/BatchNor
# __________________________________________________________________________________________________
# expanded_conv_12/expand (Conv2D (None, 4, 4, 672)    75264       expanded_conv_11/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/expand/BatchNo (None, 4, 4, 672)    2688        expanded_conv_12/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None, 4, 4, 672)    0           expanded_conv_12/expand/BatchNorm
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 4, 4, 672)    0           tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_18 (TFOpLambda (None, 4, 4, 672)    0           re_lu_29[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 4, 4, 672)    0           expanded_conv_12/expand/BatchNorm
#                                                                  tf.math.multiply_18[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/depthwise/pad  (None, 7, 7, 672)    0           multiply_13[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/depthwise (Dep (None, 2, 2, 672)    16800       expanded_conv_12/depthwise/pad[0]
# __________________________________________________________________________________________________
# expanded_conv_12/depthwise/Batc (None, 2, 2, 672)    2688        expanded_conv_12/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 2, 2, 672)    0           expanded_conv_12/depthwise/BatchN
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 2, 2, 672)    0           tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 2, 2, 672)    0           re_lu_30[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 2, 2, 672)    0           expanded_conv_12/depthwise/BatchN
#                                                                  tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/squeeze_excite (None, 1, 1, 672)    0           multiply_14[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/squeeze_excite (None, 1, 1, 168)    113064      expanded_conv_12/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_12/squeeze_excite (None, 1, 1, 168)    0           expanded_conv_12/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_12/squeeze_excite (None, 1, 1, 672)    113568      expanded_conv_12/squeeze_excite/R
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 1, 1, 672)    0           expanded_conv_12/squeeze_excite/C
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 1, 1, 672)    0           tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 1, 1, 672)    0           re_lu_31[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/squeeze_excite (None, 2, 2, 672)    0           multiply_14[0][0]
#                                                                  tf.math.multiply_20[0][0]
# __________________________________________________________________________________________________
# expanded_conv_12/project (Conv2 (None, 2, 2, 160)    107520      expanded_conv_12/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_12/project/BatchN (None, 2, 2, 160)    640         expanded_conv_12/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/expand (Conv2D (None, 2, 2, 960)    153600      expanded_conv_12/project/BatchNor
# __________________________________________________________________________________________________
# expanded_conv_13/expand/BatchNo (None, 2, 2, 960)    3840        expanded_conv_13/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 2, 2, 960)    0           expanded_conv_13/expand/BatchNorm
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 2, 2, 960)    0           tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 2, 2, 960)    0           re_lu_32[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 2, 2, 960)    0           expanded_conv_13/expand/BatchNorm
#                                                                  tf.math.multiply_21[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/depthwise (Dep (None, 2, 2, 960)    24000       multiply_15[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/depthwise/Batc (None, 2, 2, 960)    3840        expanded_conv_13/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 2, 2, 960)    0           expanded_conv_13/depthwise/BatchN
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 2, 2, 960)    0           tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_22 (TFOpLambda (None, 2, 2, 960)    0           re_lu_33[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 2, 2, 960)    0           expanded_conv_13/depthwise/BatchN
#                                                                  tf.math.multiply_22[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/squeeze_excite (None, 1, 1, 960)    0           multiply_16[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/squeeze_excite (None, 1, 1, 240)    230640      expanded_conv_13/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_13/squeeze_excite (None, 1, 1, 240)    0           expanded_conv_13/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_13/squeeze_excite (None, 1, 1, 960)    231360      expanded_conv_13/squeeze_excite/R
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 1, 1, 960)    0           expanded_conv_13/squeeze_excite/C
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 1, 1, 960)    0           tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_23 (TFOpLambda (None, 1, 1, 960)    0           re_lu_34[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/squeeze_excite (None, 2, 2, 960)    0           multiply_16[0][0]
#                                                                  tf.math.multiply_23[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/project (Conv2 (None, 2, 2, 160)    153600      expanded_conv_13/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_13/project/BatchN (None, 2, 2, 160)    640         expanded_conv_13/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_13/Add (Add)      (None, 2, 2, 160)    0           expanded_conv_12/project/BatchNor
#                                                                  expanded_conv_13/project/BatchNor
# __________________________________________________________________________________________________
# expanded_conv_14/expand (Conv2D (None, 2, 2, 960)    153600      expanded_conv_13/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/expand/BatchNo (None, 2, 2, 960)    3840        expanded_conv_14/expand[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 2, 2, 960)    0           expanded_conv_14/expand/BatchNorm
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 2, 2, 960)    0           tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_24 (TFOpLambda (None, 2, 2, 960)    0           re_lu_35[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 2, 2, 960)    0           expanded_conv_14/expand/BatchNorm
#                                                                  tf.math.multiply_24[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/depthwise (Dep (None, 2, 2, 960)    24000       multiply_17[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/depthwise/Batc (None, 2, 2, 960)    3840        expanded_conv_14/depthwise[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 2, 2, 960)    0           expanded_conv_14/depthwise/BatchN
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 2, 2, 960)    0           tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_25 (TFOpLambda (None, 2, 2, 960)    0           re_lu_36[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 2, 2, 960)    0           expanded_conv_14/depthwise/BatchN
#                                                                  tf.math.multiply_25[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/squeeze_excite (None, 1, 1, 960)    0           multiply_18[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/squeeze_excite (None, 1, 1, 240)    230640      expanded_conv_14/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_14/squeeze_excite (None, 1, 1, 240)    0           expanded_conv_14/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_14/squeeze_excite (None, 1, 1, 960)    231360      expanded_conv_14/squeeze_excite/R
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 1, 1, 960)    0           expanded_conv_14/squeeze_excite/C
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 1, 1, 960)    0           tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_26 (TFOpLambda (None, 1, 1, 960)    0           re_lu_37[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/squeeze_excite (None, 2, 2, 960)    0           multiply_18[0][0]
#                                                                  tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/project (Conv2 (None, 2, 2, 160)    153600      expanded_conv_14/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_14/project/BatchN (None, 2, 2, 160)    640         expanded_conv_14/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_14/Add (Add)      (None, 2, 2, 160)    0           expanded_conv_13/Add[0][0]
#                                                                  expanded_conv_14/project/BatchNor
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 2, 2, 960)    153600      expanded_conv_14/Add[0][0]
# __________________________________________________________________________________________________
# Conv_1/BatchNorm (BatchNormaliz (None, 2, 2, 960)    3840        Conv_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 2, 2, 960)    0           Conv_1/BatchNorm[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 2, 2, 960)    0           tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_27 (TFOpLambda (None, 2, 2, 960)    0           re_lu_38[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 2, 2, 960)    0           Conv_1/BatchNorm[0][0]
#                                                                  tf.math.multiply_27[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1, 1, 960)    0           multiply_19[0][0]
# __________________________________________________________________________________________________
# Conv_2 (Conv2D)                 (None, 1, 1, 1280)   1230080     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 1, 1, 1280)   0           Conv_2[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 1, 1, 1280)   0           tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_28 (TFOpLambda (None, 1, 1, 1280)   0           re_lu_39[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1, 1, 1280)   0           Conv_2[0][0]
#                                                                  tf.math.multiply_28[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 1, 1280)   0           multiply_20[0][0]
# __________________________________________________________________________________________________
# Logits (Conv2D)                 (None, 1, 1, 43)     55083       dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 43)           0           Logits[0][0]
# __________________________________________________________________________________________________
# Predictions (Activation)        (None, 43)           0           flatten[0][0]
# ==================================================================================================
# Total params: 4,281,515
# Trainable params: 4,257,115
# Non-trainable params: 24,400
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
starting_time = time.time()

fullDataTrain(model,df,860)
ending_time = time.time()
total_time = ending_time - starting_time
total_time/=60

print("Time taken fit : ",total_time," min")
# Out:
# Total Mini Trainings :  101
# Epoch 1/25
# 25/25 [==============================] - 14s 232ms/step - loss: 3.6859 - accuracy: 0.0711 - val_loss: 3.7628 - val_accuracy: 0.0116
# Epoch 2/25
# 25/25 [==============================] - 4s 177ms/step - loss: 2.9772 - accuracy: 0.1835 - val_loss: 3.7646 - val_accuracy: 0.0116
# Epoch 3/25
# 25/25 [==============================] -
ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 9.5008 - val_accuracy: 0.0370
# Epoch 22/25
# 23/23 [==============================] - 4s 162ms/step - loss: 5.4333e-04 - accuracy: 1.0000 - val_loss: 10.0022 - val_accuracy: 0.0123
# Epoch 23/25
# 23/23 [==============================] - 4s 182ms/step - loss: 9.9733e-04 - accuracy: 1.0000 - val_loss: 11.0126 - val_accuracy: 0.0123
# Epoch 24/25
# 23/23 [==============================] - 4s 161ms/step - loss: 3.5090e-04 - accuracy: 1.0000 - val_loss: 10.6015 - val_accuracy: 0.0123
# Epoch 25/25
# 23/23 [==============================] - 4s 177ms/step - loss: 9.0742e-04 - accuracy: 1.0000 - val_loss: 10.8914 - val_accuracy: 0.0123
# Time taken fit :  186.95915130376815  min

# %%
#Saving the model
model.save("MobileNetV3")
# Out:
# INFO:tensorflow:Assets written to: MobileNetV3/assets
# /raid/home/dgx1442/finalYearProject/venv/lib/python3.6/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
# training_accuracy = history.history['accuracy']
# validation_accuracy = history.history['val_accuracy']
# loss = history.history['loss']
# val_loss = history.history['val_loss']

# %%
# epochs  = [x for x in range(Epochs)]
# plt.figure(figsize=(10,5))
# plt.plot(epochs,training_accuracy,color="blue",label="Training Accuracy")
# plt.plot(epochs,validation_accuracy,color="red",label="Validation Accuracy")
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()

# %%
# epochs  = [x for x in range(Epochs)]
# plt.figure(figsize=(10,5))
# plt.plot(epochs,loss,color="blue",label="training loss")
# plt.plot(epochs,val_loss,color="red",label="validation loss")
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()

# %% [markdown]
#  ***Test Image Classification and Accuracy Calculation***

# %%
#Loading weights into CNN model 
# model = tf.keras.models.load_model("MobileNetV3")

# %%
df_test = pd.read_csv(testdir)
print("Number of Test Images are ", len(df_test))
df_test.dropna()
df_test['Rotate']=0
df_test.head()
# Out:
# Number of Test Images are  12630
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path  \
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png
#
#    Rotate
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
viewStatistics(df_test)
# Out:
# Total Training Examples :  12630

# %%
showExamples(df_test)

# %%
df_test = upSampleDataFrame(df_test,750)
# Out:
# Total number of images after Upsampling:  32250
#
#
# Time taken to upsample images :  0.030435470740000407  min

# %%
df_test.describe()
# Out:
#               Width        Height        Roi.X1        Roi.Y1        Roi.X2  \
# count  32250.000000  32250.000000  32250.000000  32250.000000  32250.000000
# mean      52.765178     52.229054      6.130202      6.099287     46.977054
# std       28.815946     26.647065      1.863877      1.672995     27.192324
# min       25.000000     25.000000      1.000000      5.000000     20.000000
# 25%       34.000000     35.000000      5.000000      5.000000     29.000000
# 50%       43.000000     44.000000      6.000000      6.000000     38.000000
# 75%       60.000000     60.000000      6.000000      6.000000     55.000000
# max      266.000000    232.000000     23.000000     19.000000    244.000000
#
#              Roi.Y2       ClassId        Rotate
# count  32250.000000  32250.000000  32250.000000
# mean      46.502884     21.000000    108.643194
# std       25.179662     12.409866    119.004168
# min       20.000000      0.000000      0.000000
# 25%       30.000000     10.000000      0.000000
# 50%       39.000000     21.000000     64.000000
# 75%       55.000000     32.000000    210.000000
# max      212.000000     42.000000    359.000000

# %%
# Test Images Prediction
y_test,y_pred = PredictTest(model,df_test)

# %%
confusion = confusion_matrix(y_test, y_pred)

# Calculate accuracy
accuracy = np.sum(np.diag(confusion)) / np.sum(confusion)
print("Total Accuracy: ", accuracy*100)

# Calculate precision, recall, and F1-score
classification_rep = classification_report(y_test, y_pred, labels=np.unique(y_pred))

# Print the results
print("\nConfusion Matrix:\n", confusion)


lines = classification_rep.split('\n')
data = []

for line in lines[2:-5]:  # Exclude header and footer lines
    row_data = line.split()
    if len(row_data) > 0:
        class_name = row_data[0]
        precision = float(row_data[1])
        recall = float(row_data[2])
        f1_score = float(row_data[3])
        support = int(row_data[4])
        data.append([class_name, precision, recall, f1_score, support])

# Create a DataFrame
report = pd.DataFrame(data, columns=['Class', 'Precision', 'Recall', 'F1-Score', 'Support'])
# Print the DataFrame
print("\n\n\n Summarizing the results : ")
report
# Out:
# Total Accuracy:  3.758139534883721
#
# Confusion Matrix:
#  [[   0    0    0 ...  482    0    0]
#  [   0    0    0 ... 1068    0    0]
#  [   0    0    0 ...  900    0    0]
#  ...
#  [   0    0    0 ...  815    0    0]
#  [   0    0    0 ... 1108    0    0]
#  [   0    0    0 ...  478    0    0]]
#
#
#
#  Summarizing the results :
#    Class  Precision  Recall  F1-Score  Support
# 0     11       1.00    0.01      0.03      392
# 1     13       1.00    0.10      0.18      857
# 2     18       0.00    0.00      0.00      768
# 3     25       0.28    0.17      0.21     1023
# 4     28       0.00    0.00      0.00      483
# 5     29       0.00    0.00      0.00      770
# 6     33       0.18    0.09      0.12      486
# 7     34       0.19    0.12      0.14      781
# 8     35       0.00    0.00      0.00      817
# 9     36       0.00    0.00      0.00      604
# 10    37       0.00    0.00      0.00      735
# 11    40       0.03    1.00      0.05      817

# %%
df_test.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path  \
# 0     31      36       5       6      26      31       39  Test/10721.png
# 1     29      30       5       6      24      25        5  Test/09946.png
# 2     51      48       5       6      46      42       24  Test/07824.png
# 3     51      50       6       6      46      45       36  Test/03418.png
# 4    109      97      10       9     100      89       24  Test/02396.png
#
#    Rotate
# 0     338
# 1      19
# 2       0
# 3     313
# 4     170

# %%
# Testing one Random Image from test data 
test_length = len(df_test)
select_row  = np.random.randint(0, test_length-1)
row = df_test.iloc[select_row]
print("Original Value : ",df_test.iloc[select_row,6])
img = Image.open(directory+row.iloc[7])
img = img.crop((row.iloc[2],row.iloc[3],row.iloc[4],row.iloc[5]))
img = img.resize((resize_x,resize_y))
plt.imshow(img)
img  = np.array(img)
img  = tf.convert_to_tensor(img,dtype=float)
img = img/255.0
img = tf.expand_dims(img, axis=0)
probability = model.predict(img)
value = get_max_index(probability[0])
print("Predicted Value : ",value)
# Out:
# Original Value :  25
# Predicted Value :  40

# %%
class_names = []
for i in range(num_of_classes):
    class_names.append("Class "+str(i))
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion, annot=False, cmap="viridis", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
